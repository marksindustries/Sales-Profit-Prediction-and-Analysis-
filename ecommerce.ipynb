# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import shap

# %% [markdown]
# ### Data : Train (70%) | Test (30%)
#
#             V.Good     | V. Poor  (High Variance)

# %%
Train : Classication : Accuracy : 95%
Test : Classication : Accuracy : 90 - 95% | 50%

High Variant : Model

# %% [markdown]
# ## High Bias : Model is too simple
# ## High Variance : Model is not consistent with result
#
#
# ## "Low Bias and Low Variance"

# %% [markdown]
# ## 1. Data Extraction

# %%
data = pd.read_csv('/Users/rohanpatil/Desktop/Rohan Patil - DSAI/Course Notebooks/projects/ecommerce/data.csv')

# %%
data.columns = data.columns.str.lower()

# %%
data.head()
# Out:
#    order id  order date customer name region       city   category  \
# 0     10001  2024-10-19  Kashvi Varty  South  Bangalore      Books
# 1     10002  2025-08-30   Advik Desai  North      Delhi  Groceries
# 2     10003  2023-11-04    Rhea Kalla   East      Patna    Kitchen
# 3     10004  2025-05-23     Anika Sen   East    Kolkata  Groceries
# 4     10005  2025-01-19   Akarsh Kaul   West       Pune   Clothing
#
#   sub-category       product name  quantity  unit price  discount     sales  \
# 0  Non-Fiction  Non-Fiction Ipsum         2       36294         5   68958.6
# 1         Rice          Rice Nemo         1       42165        20   33732.0
# 2       Juicer        Juicer Odio         4       64876        20  207603.2
# 3          Oil      Oil Doloribus         5       37320        15  158610.0
# 4    Kids Wear      Kids Wear Quo         1       50037        10   45033.3
#
#      profit payment mode
# 0  10525.09   Debit Card
# 1   6299.66   Debit Card
# 2  19850.27  Credit Card
# 3  36311.02          UPI
# 4   9050.04   Debit Card

# %%
data.columns
# Out:
# Index(['order id', 'order date', 'customer name', 'region', 'city', 'category',
#        'sub-category', 'product name', 'quantity', 'unit price', 'discount',
#        'sales', 'profit', 'payment mode'],
#       dtype='object')

# %% [markdown]
# ## 2. Data Analysis

# %% [markdown]
# ## Findings :
# ### 1. Most Profitable Region : North

# %%
data['region'].unique()
# Out:
# array(['South', 'North', 'East', 'West'], dtype=object)

# %%
data.groupby(['region'])['profit'].mean()
# Out:
# region
# East     16347.578121
# North    16570.655536
# South    15023.085860
# West     15777.697937
# Name: profit, dtype: float64

# %%
sns.barplot(x='region', y='profit', data=data)
# Out:
# <Axes: xlabel='region', ylabel='profit'>

# %%
data.groupby(['region'])['city'].count()
# Out:
# region
# East     1256
# North    1288
# South    1215
# West     1241
# Name: city, dtype: int64

# %% [markdown]
# ## South Bangalore Avg_Profits

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = 'region', y='profit', data=data, hue='city')
# Out:
# <Axes: xlabel='region', ylabel='profit'>

# %% [markdown]
# ## Which Region Sold the highest no. of books ?

# %%
data[data['category']== 'Books'].groupby(['region','category'])['quantity'].count()
# Out:
# region  category
# East    Books       128
# North   Books       143
# South   Books       121
# West    Books       136
# Name: quantity, dtype: int64

# %% [markdown]
# ## Which Sub - category has the highest average discount ?

# %%
data.groupby(['sub-category'])['discount'].mean().sort_values(ascending=False).head(3)
# Out:
# sub-category
# Puzzle     11.329787
# Shampoo    11.091954
# Camera     10.957447
# Name: discount, dtype: float64

# %% [markdown]
# ## South : Region , Category : Kitchen
# ### 1) Payment Mode Count 2) Total Sales 3) Total Profit 4) Quntity Sold

# %%
df = data[ (data['region'] =='South') & (data['category'] == 'Kitchen') ]

# %%
df.head()
# Out:
#      order id  order date   customer name region        city category  \
# 61      10062  2024-04-09      Azad Kunda  South     Chennai  Kitchen
# 163     10164  2024-06-21  Inaaya  Tandon  South   Hyderabad  Kitchen
# 186     10187  2024-08-03   Samiha Halder  South   Hyderabad  Kitchen
# 263     10264  2024-02-05  Drishya Mangal  South  Coimbatore  Kitchen
# 304     10305  2025-08-31   Vedika Shetty  South     Chennai  Kitchen
#
#      sub-category           product name  quantity  unit price  discount  \
# 61   Cookware Set      Cookware Set Nisi         2       13751        15
# 163        Juicer        Juicer Possimus         5       44801        15
# 186  Cookware Set    Cookware Set Minima         2        8566        15
# 263        Juicer       Juicer Voluptate         4       39061        20
# 304  Cookware Set  Cookware Set Eligendi         4       18577         0
#
#          sales    profit payment mode
# 61    23376.70   5552.74   Debit Card
# 163  190404.25  16507.93          UPI
# 186   14562.20   2893.23  Credit Card
# 263  124995.20  30886.70  Credit Card
# 304   74308.00   9828.04          UPI

# %% [markdown]
# ## Which category has the highest profit percentage in region (South, North)

# %%
df['payment mode'].value_counts()
# Out:
# payment mode
# Net Banking    27
# Debit Card     26
# UPI            25
# Credit Card    23
# COD            23
# Name: count, dtype: int64

# %%
df['sales'].sum()
# Out:
# 13399212.0

# %%
df['sales'].mean()
# Out:
# 108058.16129032258

# %%
df['sales'].agg({'total_sales': 'sum',
                   'average_sales': 'mean'
                   })
# Out:
# total_sales      1.339921e+07
# average_sales    1.080582e+05
# Name: sales, dtype: float64

# %%
df['quantity'].count()
# Out:
# 124

# %%
df.agg({'sales': ['sum', 'mean'],
            'quantity': ['sum'],})
# Out:
#              sales  quantity
# sum   1.339921e+07     373.0
# mean  1.080582e+05       NaN

# %%
df.head()
# Out:
#      order id  order date   customer name region        city category  \
# 61      10062  2024-04-09      Azad Kunda  South     Chennai  Kitchen
# 163     10164  2024-06-21  Inaaya  Tandon  South   Hyderabad  Kitchen
# 186     10187  2024-08-03   Samiha Halder  South   Hyderabad  Kitchen
# 263     10264  2024-02-05  Drishya Mangal  South  Coimbatore  Kitchen
# 304     10305  2025-08-31   Vedika Shetty  South     Chennai  Kitchen
#
#      sub-category           product name  quantity  unit price  discount  \
# 61   Cookware Set      Cookware Set Nisi         2       13751        15
# 163        Juicer        Juicer Possimus         5       44801        15
# 186  Cookware Set    Cookware Set Minima         2        8566        15
# 263        Juicer       Juicer Voluptate         4       39061        20
# 304  Cookware Set  Cookware Set Eligendi         4       18577         0
#
#          sales    profit payment mode
# 61    23376.70   5552.74   Debit Card
# 163  190404.25  16507.93          UPI
# 186   14562.20   2893.23  Credit Card
# 263  124995.20  30886.70  Credit Card
# 304   74308.00   9828.04          UPI

# %%
df.shape
# Out:
# (124, 14)

# %% [markdown]
# ## Which category has the highest profit percentage in region (South, North)

# %%
df = data[(data['region'] == 'North') | (data['region'] == 'South')]

# %%
df = data[data['region'].isin(['North', 'South'])]

# %%
df.head()
# Out:
#     order id  order date    customer name region       city   category  \
# 0      10001  2024-10-19     Kashvi Varty  South  Bangalore      Books
# 1      10002  2025-08-30      Advik Desai  North      Delhi  Groceries
# 7      10008  2025-08-17        Misha Dua  North    Lucknow      Books
# 8      10009  2025-03-07      Arhaan Vala  North     Jaipur  Groceries
# 10     10011  2025-08-24  Divyansh Thaman  North    Lucknow    Kitchen
#
#     sub-category             product name  quantity  unit price  discount  \
# 0    Non-Fiction        Non-Fiction Ipsum         2       36294         5
# 1           Rice                Rice Nemo         1       42165        20
# 7      Biography            Biography Vel         1       15885        10
# 8         Spices          Spices Expedita         1       40834        20
# 10  Cookware Set  Cookware Set Doloremque         2       10761        20
#
#       sales    profit payment mode
# 0   68958.6  10525.09   Debit Card
# 1   33732.0   6299.66   Debit Card
# 7   14296.5   1289.03   Debit Card
# 8   32667.2   3700.89  Credit Card
# 10  17217.6   4139.82  Credit Card

# %%
df['profit_percentage'] = df['profit'] / df['sales'] * 100
# Out:
# /var/folders/h8/x2xfqyjs5cl005fb579670gw0000gn/T/ipykernel_8719/2024276389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['profit_percentage'] = df['profit'] / df['sales'] * 100

# %%
df.head()
# Out:
#     order id  order date    customer name region       city   category  \
# 0      10001  2024-10-19     Kashvi Varty  South  Bangalore      Books
# 1      10002  2025-08-30      Advik Desai  North      Delhi  Groceries
# 7      10008  2025-08-17        Misha Dua  North    Lucknow      Books
# 8      10009  2025-03-07      Arhaan Vala  North     Jaipur  Groceries
# 10     10011  2025-08-24  Divyansh Thaman  North    Lucknow    Kitchen
#
#     sub-category             product name  quantity  unit price  discount  \
# 0    Non-Fiction        Non-Fiction Ipsum         2       36294         5
# 1           Rice                Rice Nemo         1       42165        20
# 7      Biography            Biography Vel         1       15885        10
# 8         Spices          Spices Expedita         1       40834        20
# 10  Cookware Set  Cookware Set Doloremque         2       10761        20
#
#       sales    profit payment mode  profit_percentage
# 0   68958.6  10525.09   Debit Card          15.262911
# 1   33732.0   6299.66   Debit Card          18.675620
# 7   14296.5   1289.03   Debit Card           9.016403
# 8   32667.2   3700.89  Credit Card          11.329070
# 10  17217.6   4139.82  Credit Card          24.044118

# %%
df.groupby(['category'])['profit_percentage'].mean().sort_values(ascending=False)
# Out:
# category
# Electronics    15.504515
# Toys           15.234720
# Home Decor     15.046251
# Kitchen        15.028310
# Furniture      14.976600
# Clothing       14.974555
# Groceries      14.920975
# Sports         14.847864
# Books          14.424683
# Beauty         14.116591
# Name: profit_percentage, dtype: float64

# %%
data['profit_percentage'] = data['profit'] / data['sales'] * 100

# %%
print(data.groupby(['region','category'])['profit_percentage'].mean())
# Out:
# region  category
# East    Beauty         14.818458
#         Books          14.602503
#         Clothing       15.846636
#         Electronics    15.403052
#         Furniture      14.764503
#         Groceries      14.786294
#         Home Decor     14.957937
#         Kitchen        14.249116
#         Sports         14.757169
#         Toys           14.897199
# North   Beauty         13.281567
#         Books          13.892981
#         Clothing       14.841311
#         Electronics    16.228859
#         Furniture      15.323202
#         Groceries      15.049144
#         Home Decor     14.943151
#         Kitchen        15.177975
#         Sports         14.846858
#         Toys           14.893888
# South   Beauty         15.058866
#         Books          15.053059
#         Clothing       15.099045
#         Electronics    14.736460
#         Furniture      14.586671
#         Groceries      14.783030
#         Home Decor     15.175344
#         Kitchen        14.888302
#         Sports         14.848951
#         Toys           15.530285
# West    Beauty         14.489345
#         Books          15.161467
#         Clothing       15.027289
#         Electronics    15.112572
#         Furniture      15.548774
#         Groceries      15.241137
#         Home Decor     14.804935
#         Kitchen        14.757934
#         Sports         14.755037
#         Toys           14.729855
# Name: profit_percentage, dtype: float64

# %%
data.head()
# Out:
#    order id  order date customer name region       city   category  \
# 0     10001  2024-10-19  Kashvi Varty  South  Bangalore      Books
# 1     10002  2025-08-30   Advik Desai  North      Delhi  Groceries
# 2     10003  2023-11-04    Rhea Kalla   East      Patna    Kitchen
# 3     10004  2025-05-23     Anika Sen   East    Kolkata  Groceries
# 4     10005  2025-01-19   Akarsh Kaul   West       Pune   Clothing
#
#   sub-category       product name  quantity  unit price  discount     sales  \
# 0  Non-Fiction  Non-Fiction Ipsum         2       36294         5   68958.6
# 1         Rice          Rice Nemo         1       42165        20   33732.0
# 2       Juicer        Juicer Odio         4       64876        20  207603.2
# 3          Oil      Oil Doloribus         5       37320        15  158610.0
# 4    Kids Wear      Kids Wear Quo         1       50037        10   45033.3
#
#      profit payment mode  profit_percentage
# 0  10525.09   Debit Card          15.262911
# 1   6299.66   Debit Card          18.675620
# 2  19850.27  Credit Card           9.561640
# 3  36311.02          UPI          22.893273
# 4   9050.04   Debit Card          20.096329

# %%
new_data = data[['region','city','category','sub-category','sales','profit','profit_percentage','unit price', 'discount','payment mode']]

# %%
new_data.head()
# Out:
#   region       city   category sub-category     sales    profit  \
# 0  South  Bangalore      Books  Non-Fiction   68958.6  10525.09
# 1  North      Delhi  Groceries         Rice   33732.0   6299.66
# 2   East      Patna    Kitchen       Juicer  207603.2  19850.27
# 3   East    Kolkata  Groceries          Oil  158610.0  36311.02
# 4   West       Pune   Clothing    Kids Wear   45033.3   9050.04
#
#    profit_percentage  unit price  discount payment mode
# 0          15.262911       36294         5   Debit Card
# 1          18.675620       42165        20   Debit Card
# 2           9.561640       64876        20  Credit Card
# 3          22.893273       37320        15          UPI
# 4          20.096329       50037        10   Debit Card

# %% [markdown]
# ### Target : Profit(Quanitative)
#
# ### Target : Region (Qualitative)

# %% [markdown]
# ## Qualatitve : Classification
# ## Quantative : Regression

# %%
X = new_data.drop('profit', axis=1)

# %%
y = new_data['profit']

# %%
X
# Out:
#      region       city     category sub-category     sales  profit_percentage  \
# 0     South  Bangalore        Books  Non-Fiction   68958.6          15.262911
# 1     North      Delhi    Groceries         Rice   33732.0          18.675620
# 2      East      Patna      Kitchen       Juicer  207603.2           9.561640
# 3      East    Kolkata    Groceries          Oil  158610.0          22.893273
# 4      West       Pune     Clothing    Kids Wear   45033.3          20.096329
# ...     ...        ...          ...          ...       ...                ...
# 4995   East    Kolkata        Books      Fiction  182013.0           6.512255
# 4996  North     Jaipur         Toys         Doll  350240.0           8.918807
# 4997  South  Bangalore       Beauty     Lipstick   35837.7          21.841524
# 4998   East    Kolkata  Electronics   Smartwatch   48844.8          13.520088
# 4999   West        Goa     Clothing    Kids Wear   69085.8           8.374876
#
#       unit price  discount payment mode
# 0          36294         5   Debit Card
# 1          42165        20   Debit Card
# 2          64876        20  Credit Card
# 3          37320        15          UPI
# 4          50037        10   Debit Card
# ...          ...       ...          ...
# 4995       60671         0   Debit Card
# 4996       70048         0  Credit Card
# 4997       42162        15   Debit Card
# 4998       13568        10  Credit Card
# 4999       76762        10  Net Banking
#
# [5000 rows x 9 columns]

# %%
y
# Out:
# 0       10525.09
# 1        6299.66
# 2       19850.27
# 3       36311.02
# 4        9050.04
#           ...
# 4995    11853.15
# 4996    31237.23
# 4997     7827.50
# 4998     6603.86
# 4999     5785.85
# Name: profit, Length: 5000, dtype: float64

# %%
X_transformed = pd.get_dummies(X, columns=['region','city','category','sub-category','payment mode'])

# %%
X_transformed.shape
# Out:
# (5000, 93)

# %%
y
# Out:
# 0       10525.09
# 1        6299.66
# 2       19850.27
# 3       36311.02
# 4        9050.04
#           ...
# 4995    11853.15
# 4996    31237.23
# 4997     7827.50
# 4998     6603.86
# 4999     5785.85
# Name: profit, Length: 5000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test , y_train , y_test = train_test_split(X_transformed, y, test_size=0.3, random_state=42)

# %%
data.shape
# Out:
# (5000, 15)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((3500, 93), (1500, 93), (3500,), (1500,))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(x_test)

# %%
print(y_pred)
# Out:
# [  917.93 43805.32 20965.   ...  8034.97  8010.29 13670.89]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)

# %%
mae
# Out:
# 596.77206

# %%
mae
# Out:
# 596.77206

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 0.9945922185326068

# %%
r2
# Out:
# 0.9945922185326068

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 1227039.8462395335

# %%
mse
# Out:
# 1227039.8462395335

# %%
new_data
# Out:
#      region       city     category sub-category     sales    profit  \
# 0     South  Bangalore        Books  Non-Fiction   68958.6  10525.09
# 1     North      Delhi    Groceries         Rice   33732.0   6299.66
# 2      East      Patna      Kitchen       Juicer  207603.2  19850.27
# 3      East    Kolkata    Groceries          Oil  158610.0  36311.02
# 4      West       Pune     Clothing    Kids Wear   45033.3   9050.04
# ...     ...        ...          ...          ...       ...       ...
# 4995   East    Kolkata        Books      Fiction  182013.0  11853.15
# 4996  North     Jaipur         Toys         Doll  350240.0  31237.23
# 4997  South  Bangalore       Beauty     Lipstick   35837.7   7827.50
# 4998   East    Kolkata  Electronics   Smartwatch   48844.8   6603.86
# 4999   West        Goa     Clothing    Kids Wear   69085.8   5785.85
#
#       profit_percentage  unit price  discount payment mode
# 0             15.262911       36294         5   Debit Card
# 1             18.675620       42165        20   Debit Card
# 2              9.561640       64876        20  Credit Card
# 3             22.893273       37320        15          UPI
# 4             20.096329       50037        10   Debit Card
# ...                 ...         ...       ...          ...
# 4995           6.512255       60671         0   Debit Card
# 4996           8.918807       70048         0  Credit Card
# 4997          21.841524       42162        15   Debit Card
# 4998          13.520088       13568        10  Credit Card
# 4999           8.374876       76762        10  Net Banking
#
# [5000 rows x 10 columns]

# %%
x_new = pd.DataFrame(x_test.iloc[0]).T

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(x_test)

# %%
shap.summary_plot(shap_values, x_test, plot_type="bar")

# %%
# -------------------------------
# 5. Detailed Beeswarm (per-sample feature impact)
# -------------------------------
shap.summary_plot(shap_values, x_test)

# %%
# -------------------------------
# 6. Single Prediction Explanation (pick 1 test sample)
# -------------------------------
i = 10  # index of test instance
shap.force_plot(explainer.expected_value, shap_values[i], x_test.iloc[i], matplotlib=True)
